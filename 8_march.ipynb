# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyadarshini-yadav13/priya13/blob/main/8_march.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Question no 1:-Import the data and get idea about data.

# %%
#Answer:-

# %%
#importing data
df=pd.read_csv("/content/ds_salaries.csv")
df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
#Question no 2:-getting an idea about duplicates and null values in the data
 and treat them if necessary...

# %%
#Answer:getting an idea about duplicate
df.duplicated().sum()
# Out:
# 1171

# %%
#drop the duplicate value
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Question no 3:-Getting an idea about the datatypes of the column
and comment whether they are correct datatype or not...

# %%
#Solution:-Getting an idea about datatypes
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
#Conclusions-all the columns are in correct datatypes as expected.

# %%
#Question no5:-Perform statistical analysis on data and comment on it.

# %%
#solution:-
df.describe().round(2)
# Out:
#        work_year       salary  salary_in_usd  remote_ratio
# count    2584.00      2584.00        2584.00       2584.00
# mean     2022.30    210365.30      133409.28         50.48
# std         0.75    808037.54       67136.84         48.16
# min      2020.00      6000.00        5132.00          0.00
# 25%      2022.00     90000.00       84975.00          0.00
# 50%      2022.00    134630.00      130000.00         50.00
# 75%      2023.00    182562.50      175000.00        100.00
# max      2023.00  30400000.00      450000.00        100.00

# %%
#conclusions-
1.From 'year' column,we can say that we have data from 2022 to 2023.as_integer_ratio
2.From 'salary',salary_in_usd' column,we can say that the mean is significantly greater
 than median which means that there are outliers present in right tail of the data.
3.From 'remote_ratio'we can say that mean is significantly equal to median so data is not scewed

# %%
#Question no -Perform corelation analysis and comment on it.

# %%
#solution:-
plt.figure(figsize=(5,3))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.title("heatmap")
plt.show()

# %%
#conclusions
1-There is no strong corelation between any of the columns.
2-'Salary_in_usd' and 'work_year'have a weak positive corelation.it implies
 that salary increases with experience.
3-'Salary_in_usd' and 'remote_ratio'have a weak negative corelation implies
if person is working in remote place and having the same destination and
the person is working from office..both are getting significantly indifferent salaries
4-'work_year' and 'remote_ratio'have a weak negative corelation implies that as
 time is passing by less remote culture is being prefered.

# %%
#Question no 7:-Find the number of unique job tittles
and display the top 5 most frequent job tittles.

# %%
#Solution:-
df['job_title'].nunique()
# Out:
# 93

# %%
df['job_title'].unique()
# Out:
# array(['Principal Data Scientist', 'ML Engineer', 'Data Scientist',
#        'Applied Scientist', 'Data Analyst', 'Data Modeler',
#        'Research Engineer', 'Analytics Engineer',
#        'Business Intelligence Engineer', 'Machine Learning Engineer',
#        'Data Strategist', 'Data Engineer', 'Computer Vision Engineer',
#        'Data Quality Analyst', 'Compliance Data Analyst',
#        'Data Architect', 'Applied Machine Learning Engineer',
#        'AI Developer', 'Research Scientist', 'Data Analytics Manager',
#        'Business Data Analyst', 'Applied Data Scientist',
#        'Staff Data Analyst', 'ETL Engineer', 'Data DevOps Engineer',
#        'Head of Data', 'Data Science Manager', 'Data Manager',
#        'Machine Learning Researcher', 'Big Data Engineer',
#        'Data Specialist', 'Lead Data Analyst', 'BI Data Engineer',
#        'Director of Data Science', 'Machine Learning Scientist',
#        'MLOps Engineer', 'AI Scientist', 'Autonomous Vehicle Technician',
# ...

# %%
#getting the top 5 most job
df['job_title'].value_counts().head(5)
# Out:
# job_title
# Data Engineer                598
# Data Scientist               538
# Data Analyst                 396
# Machine Learning Engineer    206
# Analytics Engineer            91
# Name: count, dtype: int64

# %%
#Question no7:-plot a histogram on 'salaries on usd' and comment on it.

# %%
#Solution:-
plt.figure(figsize=(5,3))
sns.histplot(df['salary_in_usd'],bins=30,kde=True )
plt.title("histogram on salaries on usd")
plt.xlabel("salary_in_usd")
plt.ylabel("frequency")
plt.show()

# %%
#from the above plot we can say that the data is approximately normally distributed
with long right tail shows there are some outliers present in right tail.

# %%
#Question no 8:
Display the average salary for each job tittle and comment on it.

# %%
#Solution:-

# %%
df.groupby('job_title')['salary_in_usd'].mean().round(2).sort_values(ascending=False)
# Out:
# job_title
# Data Science Tech Lead           375000.00
# Cloud Data Architect             250000.00
# Data Lead                        212500.00
# Data Analytics Lead              211254.50
# Principal Data Scientist         198171.12
#                                    ...
# Autonomous Vehicle Technician     26277.50
# 3D Computer Vision Researcher     21352.25
# Staff Data Analyst                15000.00
# Product Data Scientist             8000.00
# Power BI Developer                 5409.00
# Name: salary_in_usd, Length: 93, dtype: float64

# %%
#Display the average salary for each job title
 and sort it in descending order without using groupby

# %%
for j in df['job_title'].unique():
 print(j)
 print(df[df['job_title']==j]['salary_in_usd'].mean().round(2))
 print('----')
# Out:
# Principal Data Scientist
# 198171.12
# ----
# ML Engineer
# 158352.44
# ----
# Data Scientist
# 132974.59
# ----
# Applied Scientist
# 190342.58
# ----
# Data Analyst
# 105324.45
# ----
# Data Modeler
# 118900.0
# ----
# Research Engineer
# 165909.39
# ----
# Analytics Engineer
# 150151.75
# ----
# Business Intelligence Engineer
# 174150.0
# ----
# Machine Learning Engineer
# 147466.04
# ----
# Data Strategist
# 81000.0
# ----
# Data Engineer
# 139861.25
# ----
# Computer Vision Engineer
# 143536.11
# ----
# Data Quality Analyst
# 83436.0
# ----
# Compliance Data Analyst
# 30000.0
# ----
# Data Architect
# 167751.45
# ----
# Applied Machine Learning Engineer
# 99875.5
# ----
# AI Developer
# 136666.09
# ----
# Research Scientist
# 153486.37
# ----
# Data Analytics Manager
# 140630.0
# ----
# Business Data Analyst
# 66065.4
# ----
# Applied Data Scientist
# 113726.3
# ----
# Staff Data Analyst
# 15000.0
# ----
# ETL Engineer
# 71394.5
# ----
# Data DevOps Engineer
# 53654.0
# ----
# ...

# %%
#Question no 10:-Plot 'Company location' and 'average salary'

# %%
#plot company location and average salary
plt.figure(figsize=(10, 6))
sns.barplot(x='company_location', y='salary_in_usd', data=df)
plt.xticks(rotation=90)
plt.xlabel('Company Location')
plt.ylabel('Average Salary')
plt.title('Company Location vs. Average Salary')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
#Data
a=df.groupby('company_location')['salary_in_usd'].mean().round(2).sort_values(ascending=False).head(15)

# %%
#plotting
plt.figure(figsize=(5, 3))
sns.barplot(x=a.index, y=a.values)
plt.xlabel('Company Location')
plt.ylabel('Average Salary')
plt.title('Company Location vs. Average Salary')
plt.show()

# %%
#Question no 11-find the mean of multiple numeric column.

# %%
#Solution:-for this operation we need to use double bracket.
df[['salary_in_usd','salary','remote_ratio']].mean()
# Out:
# salary_in_usd    133409.280186
# salary           210365.296440
# remote_ratio         50.483746
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Question no 11:-importing the data'merc.csv'and getting the idea about it.

# %%
# Solution-Load the dataset
df2=pd.read_csv("/content/merc.csv")
df2.head()
# Out:
#       ID  model_ID  year  price  mileage  tax        mpg  engineSize  \
# 0  14568        76  2005   5200    63000  325  32.099998         1.8
# 1  14569        69  2017  34948    27000   20  61.400002         2.1
# 2  14570        75  2016  49948     6200  555  28.000000         5.5
# 3  14571        32  2016  61948    16000  325  30.400000         4.0
# 4  14572        32  2016  73948     4000  325  30.100000         4.0
#
#    transmission_ID  fuel_ID
# 0                1        5
# 1                1        3
# 2                1        5
# 3                1        5
# 4                1        5

# %%
#Question no 2:-Getting an idea about duplicate and null values and treat them if required.

# %%
#Solution-getting an idea about duplicate value n null values
df2.duplicated().sum()
# Out:
# 0

# %%
#there is no duplicate value.

# %%
df2.isnull().sum()
# Out:
# ID                 0
# model_ID           0
# year               0
# price              0
# mileage            0
# tax                0
# mpg                0
# engineSize         0
# transmission_ID    0
# fuel_ID            0
# dtype: int64

# %%
#there is no null value.

# %%
#Question no 14:-Getting an idea about data type of coloumns.

# %%
#getting an idea about datatypes
df2.dtypes
# Out:
# ID                   int64
# model_ID             int64
# year                 int64
# price                int64
# mileage              int64
# tax                  int64
# mpg                float64
# engineSize         float64
# transmission_ID      int64
# fuel_ID              int64
# dtype: object

# %%
#all the columns are in datatype as expected.

# %%
#Question no 15:-perform statistics analysis on data.

# %%
#performing statistics analysis on data.
df2.describe()
# Out:
#                  ID      model_ID          year          price        mileage  \
# count  13119.000000  13119.000000  13119.000000   13119.000000   13119.000000
# mean   21127.000000     29.306045   2017.296288   24698.596920   21949.559037
# std     3787.273426     14.862361      2.224709   11842.675542   21176.512267
# min    14568.000000      2.000000   1970.000000     650.000000       1.000000
# 25%    17847.500000     25.000000   2016.000000   17450.000000    6097.500000
# 50%    21127.000000     25.000000   2018.000000   22480.000000   15189.000000
# 75%    24406.500000     35.000000   2019.000000   28980.000000   31779.500000
# max    27686.000000     91.000000   2020.000000  159999.000000  259000.000000
#
#                 tax           mpg    engineSize  transmission_ID       fuel_ID
# count  13119.000000  13119.000000  13119.000000     13119.000000  13119.000000
# mean     129.972178     55.155843      2.071530         2.676347      2.171964
# ...

# %%
#conclusions:
1-From the "year" column, we can see that we have data from 1970 to 2020.
2-From the "price" and "mileage" column, we can see that the mean is significantly greater than median
which means that there are outliers present in right tail.
3-From the "tax" column, we can see that the mean is significantly smaller than median
which means that there are outliers present in left tail.
4-From the 'mpg' ,'engine_size'column, we can see that the mean is approximately equal to median
which means that data is symmetrically distributed.

# %%
#Question no15-perform corelation analysis on it and comment on it.

# %%
#perfoming corelation
plt.figure(figsize=(7,5))
sns.heatmap(df2.corr().round(2),annot=True)
plt.title("heatmap")
plt.show()

# %%
#Conclusion:-

1-'mileage'and'year'have strong negative correlation.
1-'mileage'and'price'have moderate negative correlation.
1-'mpg'and'tax'have moderate negative correlation.
1-'price'and'mpg'have moderate negative correlation.
1-'price'and'enginesize'have moderate possitive correlation.

# %%
#Question no 1:-plot the density curve for tax.

# %%
#plot density curve
sns.kdeplot(df2['tax'])
plt.title('Density Curve of tax')
plt.show()

# %%
#the data looks bimodal and having outliers in left tail.

# %%
#Question no 16:-plot a boxplot for 'year' and 'price'

# %%
#plot a boxplot for year and price
plt.figure(figsize=(15, 5))
sns.boxplot(x=df2['year'],y= df2['price'], data=df2,palette='Set1')
plt.title('Boxplot of Price by Year')
plt.show()

# %%
#conclusion:-
1-year 1970 seems to be outlier
2-year to 1997 till 2010 data seems to be constant range.
3-After 2010 there is linear increase in prize till 2020.
4-the number of outlier in the data from 2014 have severly increased.
