# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyadarshini-yadav13/priya13/blob/main/Pandas_3march.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#important  libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing data
df=pd.read_csv('/content/customer_booking.csv',encoding='ISO-8859-1')
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
# 2           17        Wed  AKLDEL          India                    1
# 3            4        Sat  AKLDEL    New Zealand                    0
# 4           15        Wed  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
#getting the idea about null values
df.isnull().sum().any()
# Out:
# False

# %%
#if it is true then we will use the code
df.isnull().sum()
# Out:
# num_passengers           0
# sales_channel            0
# trip_type                0
# purchase_lead            0
# length_of_stay           0
# flight_hour              0
# flight_day               0
# route                    0
# booking_origin           0
# wants_extra_baggage      0
# wants_preferred_seat     0
# wants_in_flight_meals    0
# flight_duration          0
# booking_complete         0
# dtype: int64

# %%
#getting an idea about duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
#dropping the duplicate value
df.drop_duplicates(inplace=True)

# %%
#getting the information about duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
# 2           17        Wed  AKLDEL          India                    1
# 3            4        Sat  AKLDEL    New Zealand                    0
# 4           15        Wed  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
#etting an idea about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49281 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         49281 non-null  int64
#  1   sales_channel          49281 non-null  object
#  2   trip_type              49281 non-null  object
#  3   purchase_lead          49281 non-null  int64
#  4   length_of_stay         49281 non-null  int64
#  5   flight_hour            49281 non-null  int64
#  6   flight_day             49281 non-null  object
#  7   route                  49281 non-null  object
#  8   booking_origin         49281 non-null  object
#  9   wants_extra_baggage    49281 non-null  int64
#  10  wants_preferred_seat   49281 non-null  int64
#  11  wants_in_flight_meals  49281 non-null  int64
#  12  flight_duration        49281 non-null  float64
#  13  booking_complete       49281 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
#conclusion
"wants_extra_baggage","wants_preffered_seat","wants_in_flight_meals"and "booking_complete
could be converted to boolean datatypes.
all the other datatypes in the data are in correct format.

''''
# Out:
#   File "<ipython-input-15-c64ca8c5ce41>", line 6
#     ''''
#        ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
#converting to boolean datatype
df['wants_extra_baggage']=df['wants_extra_baggage'].astype('bool')

# %%
df['wants_preferred_seat']=df['wants_preferred_seat'].astype('bool')

# %%
df['wants_in_flight_meals']=df['wants_in_flight_meals'].astype('bool')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49281 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         49281 non-null  int64
#  1   sales_channel          49281 non-null  object
#  2   trip_type              49281 non-null  object
#  3   purchase_lead          49281 non-null  int64
#  4   length_of_stay         49281 non-null  int64
#  5   flight_hour            49281 non-null  int64
#  6   flight_day             49281 non-null  object
#  7   route                  49281 non-null  object
#  8   booking_origin         49281 non-null  object
#  9   wants_extra_baggage    49281 non-null  bool
#  10  wants_preferred_seat   49281 non-null  bool
#  11  wants_in_flight_meals  49281 non-null  bool
#  12  flight_duration        49281 non-null  float64
#  13  booking_complete       49281 non-null  int64
# dtypes: bool(3), float64(1), int64(5), object(5)
# ...

# %%
df.describe()
# Out:
#        num_passengers  purchase_lead  length_of_stay   flight_hour  \
# count    49281.000000   49281.000000    49281.000000  49281.000000
# mean         1.590187      84.723281       23.053976      9.070676
# std          1.016538      90.410229       33.832149      5.413099
# min          1.000000       0.000000        0.000000      0.000000
# 25%          1.000000      21.000000        5.000000      5.000000
# 50%          1.000000      51.000000       17.000000      9.000000
# 75%          2.000000     115.000000       28.000000     13.000000
# max          9.000000     867.000000      778.000000     23.000000
#
#        wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# count         49281.000000          49281.000000           49281.000000
# mean              0.668229              0.295631               0.426635
# std               0.470854              0.456331               0.494593
# min               0.000000              0.000000               0.000000
# ...

# %%
''''
1.from the "num_passengers"columns,we can see that min,25%,50% is at 1 implies that majority of passenger is travelling solo
2.From the "purchase_lead"and"length_of_stay" column we see that mean is greater than median impling that the
outliers are present in the data in the right tail.
3.From the "flight hour" and"flight duration"column we see that mean is approximatly equal to median impling that the
data is symetric
'....

# %%
#EDA on categorical Data

# %%
df['wants_extra_baggage'].sum()
# Out:
# 32931

# %%
df['wants_preferred_seat'].sum()
# Out:
# 14569

# %%
df['wants_in_flight_meals'].sum()
# Out:
# 21025

# %%
#correlation analysis
plt.figure(figsize=(7,5))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %%
....
Conclusion--"wants_preferred_seat","wants_in_flight_meals" have the weak positive corelation
Other than this all the other features are almost unrelated.

# %%
#getting the propotion value
df['trip_type'].value_counts(normalize=True)
# Out:
# trip_type
# RoundTrip     0.989814
# OneWay        0.007833
# CircleTrip    0.002354
# Name: proportion, dtype: float64

# %%
#Conclusion--Maximum flights are round trip.

# %%
#getting the propotion value
df['sales_channel'].value_counts(normalize=True)
# Out:
# sales_channel
# Internet    0.891155
# Mobile      0.108845
# Name: proportion, dtype: float64

# %%
#majority of booking is done by internet.

# %%
#getting the propotion value
df['purchase_lead'].value_counts(normalize=True)
# Out:
# purchase_lead
# 1      0.013819
# 2      0.013514
# 6      0.013169
# 7      0.012906
# 5      0.012398
#          ...
# 463    0.000020
# 460    0.000020
# 453    0.000020
# 584    0.000020
# 867    0.000020
# Name: proportion, Length: 470, dtype: float64

# %%
#getting the propotion value
df['flight_day'].value_counts(normalize=True)
# Out:
# flight_day
# Mon    0.162091
# Wed    0.153447
# Tue    0.153365
# Thu    0.148597
# Fri    0.135651
# Sun    0.130720
# Sat    0.116130
# Name: proportion, dtype: float64

# %%
#there seems to be equal data distribution
with maximum flight on Monday.

# %%
#getting the propotion value
df['booking_origin'].value_counts(normalize=True)
# Out:
# booking_origin
# Australia               0.358982
# Malaysia                0.143159
# South Korea             0.091354
# Japan                   0.077494
# China                   0.066638
#                           ...
# Panama                  0.000020
# Tonga                   0.000020
# Tanzania                0.000020
# Bulgaria                0.000020
# Svalbard & Jan Mayen    0.000020
# Name: proportion, Length: 104, dtype: float64

# %%
#most of the flight are booked from australia.

# %%
#getting the propotion value
df['route'].value_counts(normalize=True)
# Out:
# route
# AKLKUL    0.053165
# PENTPE    0.018506
# MELSGN    0.016903
# ICNSIN    0.016091
# DMKKIX    0.014793
#             ...
# AKLHGH    0.000020
# JEDPDG    0.000020
# JEDPEN    0.000020
# DACPEK    0.000020
# MRUXIY    0.000020
# Name: proportion, Length: 799, dtype: float64

# %%
#Conclusion---AKLKUL is the most common route.
